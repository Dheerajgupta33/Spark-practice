# %%
import os
import sys

os.environ["PYSPARK_PYTHON"] = sys.executable
os.environ["PYSPARK_DRIVER_PYTHON"] = sys.executable

from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("PySparkPractice") \
    .master("local[*]") \
    .getOrCreate()

print(spark.version)
# Out:
# C:\Users\dheer\anaconda3\envs\spark311\Lib\site-packages\pyspark\testing\utils.py:127: FutureWarning: PySpark does not yet fully support pandas >= 3.0.0. Some features may not work correctly. It is recommended to use pandas < 3.0.0 for now.
#   require_minimum_pandas_version()
# 4.2.0

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
data=[(10 ,'Anil',50000, 18),
(11 ,'Vikas',75000,  16),
(12 ,'Nisha',40000,  18),
(13 ,'Nidhi',60000,  17),
(14 ,'Priya',80000,  18),
(15 ,'Mohit',45000,  18),
(16 ,'Rajesh',90000, 10),
(17 ,'Raman',55000, 16),
(18 ,'Sam',65000,   17),
(15 ,'Mohit',45000,  18),
(13 ,'Nidhi',60000,  17),      
(14 ,'Priya',90000,  18),  
(18 ,'Sam',65000,   17)
     ]
schema = ['id', 'name', 'salary', 'age']

df_1 = spark.createDataFrame(data, schema)

# %%
df_1.show()
# Out:
# +---+------+------+---+
# | id|  name|salary|age|
# +---+------+------+---+
# | 10|  Anil| 50000| 18|
# | 11| Vikas| 75000| 16|
# | 12| Nisha| 40000| 18|
# | 13| Nidhi| 60000| 17|
# | 14| Priya| 80000| 18|
# | 15| Mohit| 45000| 18|
# | 16|Rajesh| 90000| 10|
# | 17| Raman| 55000| 16|
# | 18|   Sam| 65000| 17|
# | 15| Mohit| 45000| 18|
# | 13| Nidhi| 60000| 17|
# | 14| Priya| 90000| 18|
# | 18|   Sam| 65000| 17|
# +---+------+------+---+

# %%
df_1.distinct().show()
# Out:
# +---+------+------+---+
# | id|  name|salary|age|
# +---+------+------+---+
# | 10|  Anil| 50000| 18|
# | 11| Vikas| 75000| 16|
# | 12| Nisha| 40000| 18|
# | 13| Nidhi| 60000| 17|
# | 14| Priya| 80000| 18|
# | 15| Mohit| 45000| 18|
# | 16|Rajesh| 90000| 10|
# | 17| Raman| 55000| 16|
# | 18|   Sam| 65000| 17|
# | 14| Priya| 90000| 18|
# +---+------+------+---+

# %%
df_1.distinct().count()  ## remove dublicates but show exact same not coln only
# Out:
# 10

# %%
df_1.count()
# Out:
# 13

# %%
df_1.select('id','name').distinct().show()
# Out:
# +---+------+
# | id|  name|
# +---+------+
# | 10|  Anil|
# | 11| Vikas|
# | 12| Nisha|
# | 13| Nidhi|
# | 14| Priya|
# | 15| Mohit|
# | 16|Rajesh|
# | 17| Raman|
# | 18|   Sam|
# +---+------+

# %%
dropped_df1 = df_1.drop_duplicates(['id','name','salary','age'])

# %%
df_1.sort(col('salary')).show()
# Out:
# +---+------+------+---+
# | id|  name|salary|age|
# +---+------+------+---+
# | 12| Nisha| 40000| 18|
# | 15| Mohit| 45000| 18|
# | 15| Mohit| 45000| 18|
# | 10|  Anil| 50000| 18|
# | 17| Raman| 55000| 16|
# | 13| Nidhi| 60000| 17|
# | 13| Nidhi| 60000| 17|
# | 18|   Sam| 65000| 17|
# | 18|   Sam| 65000| 17|
# | 11| Vikas| 75000| 16|
# | 14| Priya| 80000| 18|
# | 16|Rajesh| 90000| 10|
# | 14| Priya| 90000| 18|
# +---+------+------+---+

# %%
 df_1.sort(col('salary').desc()).show()
# Out:
# +---+------+------+---+
# | id|  name|salary|age|
# +---+------+------+---+
# | 16|Rajesh| 90000| 10|
# | 14| Priya| 90000| 18|
# | 14| Priya| 80000| 18|
# | 11| Vikas| 75000| 16|
# | 18|   Sam| 65000| 17|
# | 18|   Sam| 65000| 17|
# | 13| Nidhi| 60000| 17|
# | 13| Nidhi| 60000| 17|
# | 17| Raman| 55000| 16|
# | 10|  Anil| 50000| 18|
# | 15| Mohit| 45000| 18|
# | 15| Mohit| 45000| 18|
# | 12| Nisha| 40000| 18|
# +---+------+------+---+

# %%
 df_1.sort(col('salary').desc(), col('name').desc()).show()  ##pehle salary hoga then name
# Out:
# +---+------+------+---+
# | id|  name|salary|age|
# +---+------+------+---+
# | 16|Rajesh| 90000| 10|
# | 14| Priya| 90000| 18|
# | 14| Priya| 80000| 18|
# | 11| Vikas| 75000| 16|
# | 18|   Sam| 65000| 17|
# | 18|   Sam| 65000| 17|
# | 13| Nidhi| 60000| 17|
# | 13| Nidhi| 60000| 17|
# | 17| Raman| 55000| 16|
# | 10|  Anil| 50000| 18|
# | 15| Mohit| 45000| 18|
# | 15| Mohit| 45000| 18|
# | 12| Nisha| 40000| 18|
# +---+------+------+---+
